# %% [markdown]
# ### Loading the required packages

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Loading the Q1 sample CRASH dataset for further analysis of features.
#
# Data is available for each quarter(2016 Q1,Q2,Q3,Q4) as excel files. Out of the many excel sheets the main in with Crash information.
#
# This analysis is only around CRASH information and not using addtional information like Personal invloved, Weather, Vehicle type at this time. but a more detailed analysis witll cover other type of information as well.

# %%
# sheetname = ["CRASH", "PERSON", "VEHICLE", "EMS", "CIRCUM_PERSON", "CIRCUM_VEHICLE", "CIRCUM_ROAD", "CIRCUM_WEATHER"]
dateparse = lambda x: pd.datetime.strptime(x, '%m-%d-%Y %H:%M:%S')


def getData(filePath):
    crash = pd.read_excel(filePath, parse_dates={'datetime': ['ACC_DATE', 'ACC_TIME']},date_parser=dateparse,sheet_name = "CRASH",na_values=['?', -99999])
    return crash
    

data_Q1_CRASH = getData("./data/CrashData/Crash_Qtr01_2016.xlsx")
data_Q2_CRASH = getData("./data/CrashData/Crash_Qtr02_2016.xlsx")
data_Q3_CRASH = getData("./data/CrashData/Crash_Qtr03_2016.xlsx")

### TBD: some issue found with loading this file. Will need to add this data file after make some fixes.
#data_Q4_CRASH = getData("./data/CrashData/Crash_Qtr04_2016.xlsx")

# Bringing in all the data to on common data file.
df = [data_Q1_CRASH, data_Q2_CRASH, data_Q3_CRASH]
data = pd.concat(df)

# make the time of accident as the index on the datatframe for time series analysis..
data.index = pd.to_datetime(data.datetime)

# %% [markdown]
# ### Some plots below to understand the data
#
# First think first!!! Understand the data. In this problem we need to predict number of accidents daily/weekly/monthly for a given road segment or block then we will be able to better use these forecast for emergency services planning.
#
# Some of data analysis will be to understand the important features.

# %%
data["REPORT_TYPE"].value_counts().plot(kind='bar')
plt.xlabel("REPORT_TYPE")
plt.ylabel("Count")
plt.title("Breakdown of Report Type for Accidents (2016 Q1-Q3)")
# Out:
# Text(0.5,1,u'Breakdown of Report Type for Accidents (2016 Q1-Q3)')

# %% [markdown]
# ##### Shows most of the accidents are related to property damage.

# %%
data["COUNTY_NO"].value_counts().plot(kind='bar')
plt.xlabel("County Codes")
plt.ylabel("Count")
plt.title("Breakdown of Accidents by County (2016 Q1-Q3)")
# Out:
# Text(0.5,1,u'Breakdown of Accidents by County (2016 Q1-Q3)')

# %% [markdown]
# Looks from the above chart county infromation is one of the important factors of number of accidents in the county

# %%
data["WEATHER_CODE"].value_counts().plot(kind='bar')
plt.xlabel("Weather Codes")
plt.ylabel("Count")
plt.title("Breakdown of Accidents by Wether Code (2016 Q1-Q3)")
# Out:
# Text(0.5,1,u'Breakdown of Accidents by Wether Code (2016 Q1-Q3)')

# %% [markdown]
# Looks from the above weather is one of the important factors of number of accidents

# %%
data["REPORT_TYPE"].resample('M', how='count').plot()
plt.xlabel("Time")
plt.ylabel("Count")
plt.title("Month-Wise Accidents (2016 Q1-Q3)")
# Count of number of accidents with time.
# Out:
# /Users/212475040/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).count()
#   if __name__ == '__main__':
# Text(0.5,1,u'Month-Wise Accidents (2016 Q1-Q3)')

# %% [markdown]
# Some months are bad for traffic

# %%
data["REPORT_TYPE"].resample('W', how='count').plot()
plt.xlabel("Time")
plt.ylabel("Count")
plt.title("Week-Wise Accidents (2016 Q1-Q3)")
# Count of number of accidents with time.
# Out:
# /Users/212475040/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).count()
#   if __name__ == '__main__':
# Text(0.5,1,u'Week-Wise Accidents (2016 Q1-Q3)')

# %% [markdown]
# Week of month is not a big factor and looks like not a variable factor

# %%
data['hour'] = data.index.hour
data["hour"].value_counts().plot(kind='bar')
plt.title("Breakdown of Accidents by Hour (2016 Q1-Q3)")
plt.xlabel("Hours")
plt.ylabel("Count")
# Out:
# Text(0,0.5,u'Count')

# %% [markdown]
# Hour of the day is another important factor for the number of accidents
# that happen in that hour. Looks like after office are more bad than morning hours

# %% [markdown]
# ### Creating a Spatial plot of the data to under the spatial dispersion.

# %%
## Plot the accidents information from LatLong.
#temp = data_Q1_CRASH[data_Q1_CRASH["REPORT_TYPE"] != "Property Damage Crash"]
temp = data
colors = np.random.rand(temp.shape[0])
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(12, 12), dpi=80)
plt.scatter(temp["LONGITUDE"],temp["LATITUDE"],c=colors,s=10)
plt.title("Spatial Distribution of the Accidents (MARYLAND)")
plt.xlabel("Long")
plt.ylabel("Lat")
plt.show()

# %%
## Plot the accidents information from LatLong.
temp = data[data["REPORT_TYPE"] != "Property Damage Crash"]
#temp = data_Q1_CRASH
colors = np.random.rand(temp.shape[0])
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(12, 12), dpi=80)
plt.scatter(temp["LONGITUDE"],temp["LATITUDE"],c=colors,s=10)
plt.title("Spatial Distribution of the Accidents (Where poeple for injured) (MARYLAND)")
plt.xlabel("Long")
plt.ylabel("Lat")
plt.show()

# %% [markdown]
# For the plot it looks like it as mostly spread around all the state...

# %%
temp["REPORT_TYPE"].resample('M', how='count').plot()
plt.xlabel("Time")
plt.ylabel("Count")
plt.title("Month-Wise Accidents (2016 Q1-Q3)")
# Count of number of accidents with time.
# Out:
# /Users/212475040/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).count()
#   if __name__ == '__main__':
# Text(0.5,1,u'Month-Wise Accidents (2016 Q1-Q3)')

# %%
data["REPORT_TYPE"].resample('D', how='count').plot()
plt.xlabel("Time")
plt.ylabel("Count")
plt.title("Daily-Wise Accidents (2016 Q1-Q3)")
# Count of number of accidents with time.
# Out:
# /Users/212475040/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).count()
#   if __name__ == '__main__':
# Text(0.5,1,u'Daily-Wise Accidents (2016 Q1-Q3)')

# %%
temp['hour'] = temp.index.hour
temp["hour"].value_counts().plot(kind='bar')
plt.title("Breakdown of Accidents by Hour (2016 Q1-Q3)")
plt.xlabel("Hours")
plt.ylabel("Count")
# Out:
# /Users/212475040/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# Text(0,0.5,u'Count')

# %%
data['weekday'] = data.index.weekday_name
data["weekday"].value_counts().plot(kind='bar')
plt.title("Breakdown of Accidents by Hour (2016 Q1-Q3)")
plt.xlabel("Hours")
plt.ylabel("Count")
# Out:
# Text(0,0.5,u'Count')

# %% [markdown]
# ### Creating Grid for mapping the accidents to spatial grid.
# The code below is used to generate a spatial grid. Accidents will be mapped to grids for a machine leanring based prediction at grid level.

# %%
#### This code is not used as we are not mapping accidents to Grid Cells

import shapefile as shp
import math

minx,maxx,miny,maxy = -80,-74,37.75,39.75
dx = .1
dy = .1

nx = int(math.ceil(abs(maxx - minx)/dx))
ny = int(math.ceil(abs(maxy - miny)/dy))

w = shp.Writer(shp.POLYGON)
w.autoBalance = 1
w.field("ID")
id=0

for i in range(ny):
    for j in range(nx):
        id+=1
        vertices = []
        parts = []
        vertices.append([min(minx+dx*j,maxx),max(maxy-dy*i,miny)])
        vertices.append([min(minx+dx*(j+1),maxx),max(maxy-dy*i,miny)])
        vertices.append([min(minx+dx*(j+1),maxx),max(maxy-dy*(i+1),miny)])
        vertices.append([min(minx+dx*j,maxx),max(maxy-dy*(i+1),miny)])
        parts.append(vertices)
        w.poly(parts)
        w.record(id)

w.save('grid.shp')

import geopandas as gpd
shapefilepath = "./grid.shp"
gridsLayer = gpd.read_file(shapefilepath)
f, ax = plt.subplots(1, figsize=(12, 12))
ax = gridsLayer.plot(axes=ax,colormap='Greens')
plt.show()
# Out:
# /Users/212475040/anaconda/lib/python2.7/site-packages/geopandas/plotting.py:381: FutureWarning: 'colormap' is deprecated, please use 'cmap' instead (for consistency with matplotlib)
#   "(for consistency with matplotlib)", FutureWarning)
# /Users/212475040/anaconda/lib/python2.7/site-packages/geopandas/plotting.py:385: FutureWarning: 'axes' is deprecated, please use 'ax' instead (for consistency with pandas)
#   "(for consistency with pandas)", FutureWarning)

# %% [markdown]
# ###

# %%
import geopandas as gpd
shapefilepath = "./data/Grid/grid.shp"
roadnetworkwithbuffer = gpd.read_file(shapefilepath)
f, ax = plt.subplots(1, figsize=(12, 12))
ax = roadnetworkwithbuffer.plot(axes=ax,colormap='Greens')
plt.show()

# %%
from shapely.geometry import Point
geometry = [Point(xy) for xy in zip(data.LONGITUDE, data.LATITUDE)]
crs = {'init': 'epsg:4326'}
accidents_data = gpd.GeoDataFrame(data, crs=crs, geometry=geometry)

# %%
from geopandas.tools import sjoin
crash_WithRoadInfo = sjoin(accidents_data,roadnetworkwithbuffer, how="inner", op='intersects')
# Out:
# Warning: CRS does not match!

# %%
crash_WithRoadInfo.head
# Out:
# <bound method GeoDataFrame.head of                                datetime  LIGHT_CODE  COUNTY_NO  MUNI_CODE  \
# 2016-02-16 11:09:00 2016-02-16 11:09:00        1.00          1        0.0
# 2016-01-11 08:14:00 2016-01-11 08:14:00        1.00          1        0.0
# 2016-02-15 20:56:00 2016-02-15 20:56:00        3.00          1        0.0
# 2016-03-23 07:33:00 2016-03-23 07:33:00        4.00          1        0.0
# 2016-01-20 13:08:00 2016-01-20 13:08:00        1.00          1        0.0
# 2016-03-06 22:38:00 2016-03-06 22:38:00        3.00          1        0.0
# 2016-02-12 20:42:00 2016-02-12 20:42:00        4.00          1        0.0
# 2016-02-04 08:40:00 2016-02-04 08:40:00        1.00          1        0.0
# 2016-01-16 10:40:00 2016-01-16 10:40:00        1.00          1        0.0
# 2016-06-05 13:51:00 2016-06-05 13:51:00        1.00          1        0.0
# 2016-06-12 04:33:00 2016-06-12 04:33:00        4.00          1        0.0
# 2016-04-07 13:31:00 2016-04-07 13:31:00        1.00          1        0.0
# 2016-05-26 22:55:00 2016-05-26 22:55:00        4.00          1        0.0
# 2016-06-16 14:09:00 2016-06-16 14:09:00        1.00          1        0.0
# 2016-06-16 14:09:00 2016-06-16 14:09:00        0.00          1        0.0
# 2016-05-06 14:12:00 2016-05-06 14:12:00        1.00          1        0.0
# 2016-04-03 08:53:00 2016-04-03 08:53:00        1.00          1        0.0
# 2016-04-03 07:55:00 2016-04-03 07:55:00        1.00          1        0.0
# 2016-04-03 08:29:00 2016-04-03 08:29:00        1.00          1        0.0
# 2016-04-24 21:45:00 2016-04-24 21:45:00        4.00          1        0.0
# 2016-05-13 16:40:00 2016-05-13 16:40:00        1.00          1        0.0
# 2016-05-25 08:45:00 2016-05-25 08:45:00        1.00          1        NaN
# 2016-09-07 08:02:00 2016-09-07 08:02:00        1.00          1        0.0
# 2016-07-27 21:30:00 2016-07-27 21:30:00        4.00          1        0.0
# 2016-07-29 20:28:00 2016-07-29 20:28:00        6.02          1        0.0
# 2016-09-27 17:20:00 2016-09-27 17:20:00        1.00          1        0.0
# 2016-07-30 14:49:00 2016-07-30 14:49:00        1.00          1        0.0
# 2016-07-30 14:52:00 2016-07-30 14:52:00        1.00          1        0.0
# 2016-08-13 14:35:00 2016-08-13 14:35:00        1.00          1        0.0
# 2016-07-27 21:46:00 2016-07-27 21:46:00        4.00          1       93.0
# ...                                 ...         ...        ...        ...
# 2016-06-12 17:53:00 2016-06-12 17:53:00        1.00         19        0.0
# 2016-06-23 05:15:00 2016-06-23 05:15:00        5.02         19        0.0
# 2016-04-29 15:00:00 2016-04-29 15:00:00        1.00         22        0.0
# 2016-06-21 21:30:00 2016-06-21 21:30:00        3.00         23      115.0
# 2016-07-18 10:36:00 2016-07-18 10:36:00       99.00         23        NaN
# 2016-05-24 09:04:00 2016-05-24 09:04:00        1.00         23        0.0
# 2016-05-23 15:44:00 2016-05-23 15:44:00        1.00         23        0.0
# 2016-09-27 10:42:00 2016-09-27 10:42:00        1.00         23        NaN
# 2016-05-13 13:47:00 2016-05-13 13:47:00        1.00         16        NaN
# 2016-04-10 00:57:00 2016-04-10 00:57:00        3.00         15        NaN
# 2016-07-21 18:28:00 2016-07-21 18:28:00        1.00          1        0.0
# 2016-09-23 02:32:00 2016-09-23 02:32:00        4.00          1        0.0
# 2016-07-15 06:43:00 2016-07-15 06:43:00        1.00          9        0.0
# 2016-09-13 22:56:00 2016-09-13 22:56:00        4.00          9        0.0
# 2016-09-08 07:42:00 2016-09-08 07:42:00        1.00          8       88.0
# 2016-07-21 20:00:00 2016-07-21 20:00:00        5.02          9        0.0
# 2016-07-14 17:11:00 2016-07-14 17:11:00        1.00          8        0.0
# 2016-09-20 06:50:00 2016-09-20 06:50:00        5.02          9        0.0
# 2016-08-27 20:19:00 2016-08-27 20:19:00        4.00         11        0.0
# 2016-07-07 01:10:00 2016-07-07 01:10:00        4.00         11        0.0
# 2016-09-28 23:03:00 2016-09-28 23:03:00        3.00         14        0.0
# 2016-08-21 16:07:00 2016-08-21 16:07:00        1.00         14        0.0
# 2016-07-02 15:56:00 2016-07-02 15:56:00        1.00         17        0.0
# 2016-07-27 05:30:00 2016-07-27 05:30:00        4.00         20        0.0
# 2016-09-03 08:15:00 2016-09-03 08:15:00        1.00         19        0.0
# 2016-09-25 11:57:00 2016-09-25 11:57:00        4.00         21        0.0
# 2016-07-23 15:39:00 2016-07-23 15:39:00        1.00         23        0.0
# 2016-08-17 17:30:00 2016-08-17 17:30:00        1.00         24      999.0
# 2016-09-30 01:29:00 2016-09-30 01:29:00        3.00         15        NaN
# 2016-09-05 21:40:00 2016-09-05 21:40:00        3.00          2        NaN
#
#                      JUNCTION_CODE  COLLISION_TYPE_CODE  SURF_COND_CODE  \
# 2016-02-16 11:09:00           0.00                   17            4.00
# 2016-01-11 08:14:00           1.00                    3            2.00
# 2016-02-15 20:56:00           1.00                   17            6.03
# 2016-03-23 07:33:00           1.00                   17            5.00
# 2016-01-20 13:08:00           1.00                   17            2.00
# 2016-03-06 22:38:00           1.00                   17            2.00
# 2016-02-12 20:42:00           1.00                   17            4.00
# 2016-02-04 08:40:00           1.00                   17            6.03
# 2016-01-16 10:40:00           2.00                   15            2.00
# 2016-06-05 13:51:00           1.00                   17            1.00
# 2016-06-12 04:33:00           1.00                   17            2.00
# 2016-04-07 13:31:00           1.00                   17            2.00
# 2016-05-26 22:55:00           0.00                   17            2.00
# 2016-06-16 14:09:00           1.00                   17            2.00
# 2016-06-16 14:09:00           1.00                   17            2.00
# 2016-05-06 14:12:00           1.00                   17            1.00
# 2016-04-03 08:53:00           0.00                   88            4.00
# 2016-04-03 07:55:00           0.00                   17            4.00
# 2016-04-03 08:29:00           0.00                   17            4.00
# 2016-04-24 21:45:00           1.00                   17            2.00
# 2016-05-13 16:40:00           2.00                   11            2.00
# 2016-05-25 08:45:00            NaN                   88             NaN
# 2016-09-07 08:02:00           0.00                   17            1.00
# 2016-07-27 21:30:00           1.00                   17            2.00
# 2016-07-29 20:28:00           0.00                    0            2.00
# 2016-09-27 17:20:00           1.00                   17            2.00
# 2016-07-30 14:49:00           0.00                   17            1.00
# 2016-07-30 14:52:00           1.00                   17            1.00
# 2016-08-13 14:35:00           1.00                    8            2.00
# 2016-07-27 21:46:00           1.00                   12            2.00
# ...                            ...                  ...             ...
# 2016-06-12 17:53:00           8.04                   11            2.00
# 2016-06-23 05:15:00           1.00                   17            2.00
# 2016-04-29 15:00:00           1.00                   17            1.00
# 2016-06-21 21:30:00           2.00                   17            1.00
# 2016-07-18 10:36:00            NaN                   88             NaN
# 2016-05-24 09:04:00           1.00                    3            1.00
# 2016-05-23 15:44:00           1.00                   17            2.00
# 2016-09-27 10:42:00            NaN                   88             NaN
# 2016-05-13 13:47:00            NaN                   88             NaN
# 2016-04-10 00:57:00            NaN                   88             NaN
# 2016-07-21 18:28:00           1.00                   17            2.00
# 2016-09-23 02:32:00           2.00                   17            2.00
# 2016-07-15 06:43:00           1.00                   17            2.00
# 2016-09-13 22:56:00           1.00                   17            2.00
# 2016-09-08 07:42:00           1.00                    3            2.00
# 2016-07-21 20:00:00           0.00                   17            2.00
# 2016-07-14 17:11:00           1.00                    9            2.00
# 2016-09-20 06:50:00           1.00                   17            1.00
# 2016-08-27 20:19:00           1.00                   17            2.00
# 2016-07-07 01:10:00           1.00                   17            1.00
# 2016-09-28 23:03:00           0.00                   17            1.00
# 2016-08-21 16:07:00           0.00                   17            1.00
# 2016-07-02 15:56:00           1.00                   17            2.00
# 2016-07-27 05:30:00           1.00                    3            2.00
# 2016-09-03 08:15:00           1.00                   17            1.00
# 2016-09-25 11:57:00           0.00                   17            2.00
# 2016-07-23 15:39:00           0.00                   11            2.00
# 2016-08-17 17:30:00           2.00                    3           99.00
# 2016-09-30 01:29:00            NaN                   17             NaN
# 2016-09-05 21:40:00            NaN                   88             NaN
#
#                      LANE_CODE  RD_COND_CODE  RD_DIV_CODE  ...   \
# 2016-02-16 11:09:00        NaN           1.0          4.0  ...
# 2016-01-11 08:14:00        3.0           1.0          4.0  ...
# 2016-02-15 20:56:00        NaN           1.0          4.0  ...
# 2016-03-23 07:33:00        NaN           5.0          4.0  ...
# 2016-01-20 13:08:00        NaN           1.0          4.0  ...
# 2016-03-06 22:38:00        NaN           1.0          1.0  ...
# 2016-02-12 20:42:00        1.0           1.0          1.0  ...
# 2016-02-04 08:40:00        1.0           1.0          1.0  ...
# 2016-01-16 10:40:00        1.0           1.0          0.0  ...
# 2016-06-05 13:51:00        1.0           1.0          4.0  ...
# 2016-06-12 04:33:00        2.0           1.0          4.0  ...
# 2016-04-07 13:31:00        1.0           1.0          4.0  ...
# 2016-05-26 22:55:00        NaN           1.0          4.0  ...
# 2016-06-16 14:09:00        2.0           1.0          4.0  ...
# 2016-06-16 14:09:00        2.0           1.0          4.0  ...
# 2016-05-06 14:12:00        NaN           1.0          4.0  ...
# 2016-04-03 08:53:00        NaN           0.0          4.0  ...
# 2016-04-03 07:55:00        NaN           1.0          4.0  ...
# 2016-04-03 08:29:00        NaN           1.0          4.0  ...
# 2016-04-24 21:45:00        2.0           1.0          4.0  ...
# 2016-05-13 16:40:00        1.0           1.0          1.0  ...
# 2016-05-25 08:45:00        NaN           NaN          NaN  ...
# 2016-09-07 08:02:00        1.0           1.0          4.0  ...
# 2016-07-27 21:30:00        1.0           1.0          4.0  ...
# 2016-07-29 20:28:00        2.0           0.0          4.0  ...
# 2016-09-27 17:20:00        3.0           1.0          4.0  ...
# 2016-07-30 14:49:00        NaN           1.0          4.0  ...
# 2016-07-30 14:52:00        NaN           1.0          4.0  ...
# 2016-08-13 14:35:00        2.0           1.0          4.0  ...
# 2016-07-27 21:46:00        1.0           1.0          1.0  ...
# ...                        ...           ...          ...  ...
# 2016-06-12 17:53:00        1.0           1.0          1.0  ...
# 2016-06-23 05:15:00        1.0           2.0          1.0  ...
# 2016-04-29 15:00:00        1.0           1.0          1.0  ...
# 2016-06-21 21:30:00        4.0          88.0          4.0  ...
# 2016-07-18 10:36:00        NaN           NaN          NaN  ...
# 2016-05-24 09:04:00        1.0           1.0          1.0  ...
# 2016-05-23 15:44:00        1.0           1.0          1.0  ...
# 2016-09-27 10:42:00        NaN           NaN          NaN  ...
# 2016-05-13 13:47:00        NaN           NaN          NaN  ...
# 2016-04-10 00:57:00        NaN           NaN          NaN  ...
# 2016-07-21 18:28:00        1.0           1.0          3.0  ...
# 2016-09-23 02:32:00        NaN           1.0          1.0  ...
# 2016-07-15 06:43:00        1.0           1.0          1.0  ...
# 2016-09-13 22:56:00        NaN           1.0          1.0  ...
# 2016-09-08 07:42:00        1.0           1.0          1.0  ...
# 2016-07-21 20:00:00        1.0           1.0          1.0  ...
# 2016-07-14 17:11:00        3.0           1.0          4.0  ...
# 2016-09-20 06:50:00        1.0           1.0          1.0  ...
# 2016-08-27 20:19:00        1.0           1.0          1.0  ...
# 2016-07-07 01:10:00        1.0           1.0          1.0  ...
# 2016-09-28 23:03:00        1.0           1.0          1.0  ...
# 2016-08-21 16:07:00        1.0           1.0          1.0  ...
# 2016-07-02 15:56:00        NaN           1.0          3.0  ...
# 2016-07-27 05:30:00        1.0           1.0          1.0  ...
# 2016-09-03 08:15:00        1.0           1.0          1.0  ...
# 2016-09-25 11:57:00        1.0           1.0          1.0  ...
# 2016-07-23 15:39:00        1.0           1.0          1.0  ...
# 2016-08-17 17:30:00        NaN           1.0         99.0  ...
# 2016-09-30 01:29:00        NaN           NaN          NaN  ...
# 2016-09-05 21:40:00        NaN           NaN          NaN  ...
#
#                      REFERENCE_TYPE_CODE REFERENCE_SUFFIX  \
# 2016-02-16 11:09:00                   MD               AE
# 2016-01-11 08:14:00                   UU              NaN
# 2016-02-15 20:56:00                   MD               AD
# 2016-03-23 07:33:00                   UU              NaN
# 2016-01-20 13:08:00                   MD              NaN
# 2016-03-06 22:38:00                   UU              NaN
# 2016-02-12 20:42:00                   CO              NaN
# 2016-02-04 08:40:00                   CO              NaN
# 2016-01-16 10:40:00                   CO              NaN
# 2016-06-05 13:51:00                   MD               AD
# 2016-06-12 04:33:00                   UU              NaN
# 2016-04-07 13:31:00                   UU              NaN
# 2016-05-26 22:55:00                   RP              NaN
# 2016-06-16 14:09:00                   UU              NaN
# 2016-06-16 14:09:00                   UU              NaN
# 2016-05-06 14:12:00                   CO              NaN
# 2016-04-03 08:53:00                   CO              NaN
# 2016-04-03 07:55:00                   CO              NaN
# 2016-04-03 08:29:00                   CO              NaN
# 2016-04-24 21:45:00                   UU              NaN
# 2016-05-13 16:40:00                   SR              NaN
# 2016-05-25 08:45:00                  NaN              NaN
# 2016-09-07 08:02:00                   UU              NaN
# 2016-07-27 21:30:00                   MD               AD
# 2016-07-29 20:28:00                   MD              NaN
# 2016-09-27 17:20:00                   UU              NaN
# 2016-07-30 14:49:00                   UU              NaN
# 2016-07-30 14:52:00                   CO              NaN
# 2016-08-13 14:35:00                   UU              NaN
# 2016-07-27 21:46:00                   UU              NaN
# ...                                  ...              ...
# 2016-06-12 17:53:00                   CO              NaN
# 2016-06-23 05:15:00                   CO              NaN
# 2016-04-29 15:00:00                   CO              NaN
# 2016-06-21 21:30:00                   MU              NaN
# 2016-07-18 10:36:00                  NaN              NaN
# 2016-05-24 09:04:00                   CO              NaN
# 2016-05-23 15:44:00                   CO              NaN
# 2016-09-27 10:42:00                  NaN              NaN
# 2016-05-13 13:47:00                  NaN              NaN
# 2016-04-10 00:57:00                  NaN              NaN
# 2016-07-21 18:28:00                   CO              NaN
# 2016-09-23 02:32:00                   MD              NaN
# 2016-07-15 06:43:00                   CO              NaN
# 2016-09-13 22:56:00                   CO              NaN
# 2016-09-08 07:42:00                   MU              NaN
# 2016-07-21 20:00:00                   CO              NaN
# 2016-07-14 17:11:00                   MD               BU
# 2016-09-20 06:50:00                   UU              NaN
# 2016-08-27 20:19:00                   CO              NaN
# 2016-07-07 01:10:00                   MD              NaN
# 2016-09-28 23:03:00                   CO              NaN
# 2016-08-21 16:07:00                   CO              NaN
# 2016-07-02 15:56:00                   CO              NaN
# 2016-07-27 05:30:00                   CO              NaN
# 2016-09-03 08:15:00                   CO              NaN
# 2016-09-25 11:57:00                   CO              NaN
# 2016-07-23 15:39:00                   CO              NaN
# 2016-08-17 17:30:00                   MD              NaN
# 2016-09-30 01:29:00                  NaN              NaN
# 2016-09-05 21:40:00                  NaN              NaN
#
#                               REFERENCE_ROAD_NAME   LATITUDE  LONGITUDE hour  \
# 2016-02-16 11:09:00                  ROCKY GAP RD  39.685487 -78.663731   11
# 2016-01-11 08:14:00                      EXIT #50  39.694548 -78.646117    8
# 2016-02-15 20:56:00            PLEASANT VALLEY RD  39.692434 -78.655065   20
# 2016-03-23 07:33:00                      EXIT #52  39.704880 -78.626501    7
# 2016-01-20 13:08:00                 NATIONAL PIKE  39.712112 -78.617912   13
# 2016-03-06 22:38:00           PERIWINKLE RD (PVT)  39.695226 -78.643433   22
# 2016-02-12 20:42:00                      HAZEN RD  39.711516 -78.699279   20
# 2016-02-04 08:40:00                GRABENSTEIN RD  39.676905 -78.696914    8
# 2016-01-16 10:40:00                   OLD LAKE DR  39.694980 -78.645983   10
# 2016-06-05 13:51:00            PLEASANT VALLEY RD  39.694135 -78.651365   13
# 2016-06-12 04:33:00              MILE MARKER 51.0  39.696538 -78.640115    4
# 2016-04-07 13:31:00              MILE MARKER 52.0  39.699058 -78.636327   13
# 2016-05-26 22:55:00  RAMP 5 FR IS 68 EB TO MD 144  39.708119 -78.620878   22
# 2016-06-16 14:09:00              MILE MARKER 53.0  39.714261 -78.613811   14
# 2016-06-16 14:09:00              MILE MARKER 53.0  39.713476 -78.615968   14
# 2016-05-06 14:12:00                     STREET RD  39.713671 -78.608187   14
# 2016-04-03 08:53:00                     STREET RD  39.714483 -78.611037    8
# 2016-04-03 07:55:00                     STREET RD  39.707285 -78.621758    7
# 2016-04-03 08:29:00                     STREET RD  39.714530 -78.612386    8
# 2016-04-24 21:45:00              MILE MARKER 54.0  39.708928 -78.601154   21
# 2016-05-13 16:40:00                   LAKEVIEW DR  39.695037 -78.650307   16
# 2016-05-25 08:45:00                           NaN  39.684389 -78.664847    8
# 2016-09-07 08:02:00                  BEGIN BRIDGE  39.671859 -78.696231    8
# 2016-07-27 21:30:00            PLEASANT VALLEY RD  39.693766 -78.652318   21
# 2016-07-29 20:28:00                 NATIONAL PIKE  39.699767 -78.635508   20
# 2016-09-27 17:20:00              MILE MARKER 52.0  39.704905 -78.627574   17
# 2016-07-30 14:49:00              MILE MARKER 52.0  39.704650 -78.628828   14
# 2016-07-30 14:52:00                     STREET RD  39.708841 -78.601280   14
# 2016-08-13 14:35:00                      EXIT #56  39.694507 -78.649063   14
# 2016-07-27 21:46:00               ENT TO BUSINESS  39.708119 -78.620878   21
# ...                                           ...        ...        ...  ...
# 2016-06-12 17:53:00              GEORGE RIGGIN RD  38.045633 -75.680481   17
# 2016-06-23 05:15:00             BACK SHELLTOWN RD  38.014155 -75.656839    5
# 2016-04-29 15:00:00                      ELSEY RD  38.271546 -75.906397   15
# 2016-06-21 21:30:00                      145TH ST  38.450523 -75.052544   21
# 2016-07-18 10:36:00                           NaN  38.450570 -75.062225   10
# 2016-05-24 09:04:00                SOUTH HILLS DR  38.238954 -75.177766    9
# 2016-05-23 15:44:00               COUNTRY CLUB RD  38.246012 -75.173265   15
# 2016-09-27 10:42:00                           NaN  38.247104 -75.155523   10
# 2016-05-13 13:47:00                           NaN  38.578232 -77.772217   13
# 2016-04-10 00:57:00                           NaN  38.771216 -79.425659    0
# 2016-07-21 18:28:00               DAVID THOMAS RD  39.542341 -78.495619   18
# 2016-09-23 02:32:00        MCCOOLE WESTERNPORT RD  39.448487 -78.971870    2
# 2016-07-15 06:43:00                      EGYPT RD  38.448785 -76.097040    6
# 2016-09-13 22:56:00                  MAPLE DAM RD  38.446665 -76.080194   22
# 2016-09-08 07:42:00                       PINE ST  38.323200 -77.160700    7
# 2016-07-21 20:00:00               HENRYS CROSS RD  38.411759 -75.875196   20
# 2016-07-14 17:11:00                LEONARDTOWN RD  38.721018 -77.130890   17
# 2016-09-20 06:50:00                      CEMETERY  38.567395 -76.110620    6
# 2016-08-27 20:19:00           MT ZION CROSSCUT RD  39.449169 -79.157739   20
# 2016-07-07 01:10:00                 KITZMILLER RD  39.399948 -79.193157    1
# 2016-09-28 23:03:00              MARTIN WAGNER RD  39.151610 -76.210510   23
# 2016-08-21 16:07:00    TOLCHESTER BEACH RD (BACK)  39.210386 -76.217750   16
# 2016-07-02 15:56:00              PETERS CORNER RD  39.160388 -75.780416   15
# 2016-07-27 05:30:00                  DONCASTER RD  37.779000 -76.128000    5
# 2016-09-03 08:15:00                 FRENCHTOWN RD  38.090042 -75.843558    8
# 2016-09-25 11:57:00             DENEEN RD (AHEAD)  39.648547 -78.253250   11
# 2016-07-23 15:39:00                RABBIT KNAW RD  38.018650 -75.398120   15
# 2016-08-17 17:30:00       ST PAUL PL (SB COUPLET)  38.773086 -75.144226   17
# 2016-09-30 01:29:00                           NaN  39.154617 -77.518708    1
# 2016-09-05 21:40:00                           NaN  37.823311 -75.548719   21
#
#                        weekday                                     geometry  \
# 2016-02-16 11:09:00    Tuesday   POINT (-78.6637308333333 39.6854873333333)
# 2016-01-11 08:14:00     Monday   POINT (-78.6461172833333 39.6945483166667)
# 2016-02-15 20:56:00     Monday   POINT (-78.6550646666667 39.6924343333333)
# 2016-03-23 07:33:00  Wednesday  POINT (-78.62650075000001 39.7048797333333)
# 2016-01-20 13:08:00  Wednesday   POINT (-78.6179117166667 39.7121124166667)
# 2016-03-06 22:38:00     Sunday   POINT (-78.6434326666667 39.6952262166667)
# 2016-02-12 20:42:00     Friday   POINT (-78.6992794275284 39.7115156926155)
# 2016-02-04 08:40:00   Thursday   POINT (-78.6969136666667 39.6769048333333)
# 2016-01-16 10:40:00   Saturday   POINT (-78.6459826666667 39.6949798333333)
# 2016-06-05 13:51:00     Sunday                 POINT (-78.651365 39.694135)
# 2016-06-12 04:33:00     Sunday   POINT (-78.6401152610779 39.6965383016664)
# 2016-04-07 13:31:00   Thursday         POINT (-78.6363266 39.6990583666667)
# 2016-05-26 22:55:00   Thursday   POINT (-78.6208784580231 39.7081193414505)
# 2016-06-16 14:09:00   Thursday  POINT (-78.61381116666669 39.7142605166667)
# 2016-06-16 14:09:00   Thursday        POINT (-78.61596830000001 39.7134756)
# 2016-05-06 14:12:00     Friday         POINT (-78.6081868166667 39.7136707)
# 2016-04-03 08:53:00     Sunday                 POINT (-78.611037 39.714483)
# 2016-04-03 07:55:00     Sunday  POINT (-78.62175783333331 39.7072848333333)
# 2016-04-03 08:29:00     Sunday   POINT (-78.6123856666667 39.7145301666667)
# 2016-04-24 21:45:00     Sunday        POINT (-78.60115385 39.7089283333333)
# 2016-05-13 16:40:00     Friday  POINT (-78.65030666666669 39.6950366666667)
# 2016-05-25 08:45:00  Wednesday   POINT (-78.6648470833333 39.6843893333333)
# 2016-09-07 08:02:00  Wednesday   POINT (-78.6962308333333 39.6718590166667)
# 2016-07-27 21:30:00  Wednesday   POINT (-78.6523184166667 39.6937664666667)
# 2016-07-29 20:28:00     Friday  POINT (-78.63550833333331 39.6997666666667)
# 2016-09-27 17:20:00    Tuesday   POINT (-78.6275743333333 39.7049051666667)
# 2016-07-30 14:49:00   Saturday           POINT (-78.6288283333333 39.70465)
# 2016-07-30 14:52:00   Saturday              POINT (-78.60127985 39.7088405)
# 2016-08-13 14:35:00   Saturday  POINT (-78.64906311035161 39.6945074985609)
# 2016-07-27 21:46:00  Wednesday   POINT (-78.6208784580231 39.7081193414505)
# ...                        ...                                          ...
# 2016-06-12 17:53:00     Sunday       POINT (-75.68048051666671 38.04563275)
# 2016-06-23 05:15:00   Thursday   POINT (-75.6568390130997 38.0141545718722)
# 2016-04-29 15:00:00     Friday        POINT (-75.90639695 38.2715455666667)
# 2016-06-21 21:30:00    Tuesday          POINT (-75.052544 38.4505231666667)
# 2016-07-18 10:36:00     Monday  POINT (-75.06222546100619 38.4505702697217)
# 2016-05-24 09:04:00    Tuesday         POINT (-75.17776600000001 38.238954)
# 2016-05-23 15:44:00     Monday                 POINT (-75.173265 38.246012)
# 2016-09-27 10:42:00    Tuesday                 POINT (-75.155523 38.247104)
# 2016-05-13 13:47:00     Friday    POINT (-77.772216796875 38.5782319658331)
# 2016-04-10 00:57:00     Sunday   POINT (-79.4256591796875 38.7712163724427)
# 2016-07-21 18:28:00   Thursday   POINT (-78.4956192970276 39.5423414336731)
# 2016-09-23 02:32:00     Friday       POINT (-78.97186961666669 39.44848695)
# 2016-07-15 06:43:00     Friday   POINT (-76.0970404744148 38.4487847730312)
# 2016-09-13 22:56:00    Tuesday   POINT (-76.0801935195923 38.4466652260825)
# 2016-09-08 07:42:00   Thursday           POINT (-77.16070000000001 38.3232)
# 2016-07-21 20:00:00   Thursday   POINT (-75.8751963078976 38.4117593754336)
# 2016-07-14 17:11:00   Thursday   POINT (-77.1308898925781 38.7210184969836)
# 2016-09-20 06:50:00    Tuesday    POINT (-76.1106204986572 38.567394695545)
# 2016-08-27 20:19:00   Saturday    POINT (-79.1577386856079 39.449169060048)
# 2016-07-07 01:10:00   Thursday   POINT (-79.1931572556496 39.3999478990648)
# 2016-09-28 23:03:00  Wednesday                   POINT (-76.21051 39.15161)
# 2016-08-21 16:07:00     Sunday  POINT (-76.21775049999999 39.2103856666667)
# 2016-07-02 15:56:00   Saturday   POINT (-75.7804164290428 39.1603882666909)
# 2016-07-27 05:30:00  Wednesday                       POINT (-76.128 37.779)
# 2016-09-03 08:15:00   Saturday   POINT (-75.8435583114624 38.0900415132243)
# 2016-09-25 11:57:00     Sunday  POINT (-78.25324952602389 39.6485466766159)
# 2016-07-23 15:39:00   Saturday          POINT (-75.39812000000001 38.01865)
# 2016-08-17 17:30:00  Wednesday   POINT (-75.1442259550095 38.7730858730332)
# 2016-09-30 01:29:00     Friday  POINT (-77.51870833333329 39.1546166666667)
# 2016-09-05 21:40:00     Monday  POINT (-75.54871916770939 37.8233109213303)
#
#                     index_right    ID
# 2016-02-16 11:09:00          13    14
# 2016-01-11 08:14:00          13    14
# 2016-02-15 20:56:00          13    14
# 2016-03-23 07:33:00          13    14
# 2016-01-20 13:08:00          13    14
# 2016-03-06 22:38:00          13    14
# 2016-02-12 20:42:00          13    14
# 2016-02-04 08:40:00          13    14
# 2016-01-16 10:40:00          13    14
# 2016-06-05 13:51:00          13    14
# 2016-06-12 04:33:00          13    14
# 2016-04-07 13:31:00          13    14
# 2016-05-26 22:55:00          13    14
# 2016-06-16 14:09:00          13    14
# 2016-06-16 14:09:00          13    14
# 2016-05-06 14:12:00          13    14
# 2016-04-03 08:53:00          13    14
# 2016-04-03 07:55:00          13    14
# 2016-04-03 08:29:00          13    14
# 2016-04-24 21:45:00          13    14
# 2016-05-13 16:40:00          13    14
# 2016-05-25 08:45:00          13    14
# 2016-09-07 08:02:00          13    14
# 2016-07-27 21:30:00          13    14
# 2016-07-29 20:28:00          13    14
# 2016-09-27 17:20:00          13    14
# 2016-07-30 14:49:00          13    14
# 2016-07-30 14:52:00          13    14
# 2016-08-13 14:35:00          13    14
# 2016-07-27 21:46:00          13    14
# ...                         ...   ...
# 2016-06-12 17:53:00        1063  1064
# 2016-06-23 05:15:00        1063  1064
# 2016-04-29 15:00:00         880   881
# 2016-06-21 21:30:00         769   770
# 2016-07-18 10:36:00         769   770
# 2016-05-24 09:04:00         948   949
# 2016-05-23 15:44:00         948   949
# 2016-09-27 10:42:00         948   949
# 2016-05-13 13:47:00         682   683
# 2016-04-10 00:57:00         545   546
# 2016-07-21 18:28:00         135   136
# 2016-09-23 02:32:00         190   191
# 2016-07-15 06:43:00         819   820
# 2016-09-13 22:56:00         819   820
# 2016-09-08 07:42:00         868   869
# 2016-07-21 20:00:00         821   822
# 2016-07-14 17:11:00         628   629
# 2016-09-20 06:50:00         698   699
# 2016-08-27 20:19:00         188   189
# 2016-07-07 01:10:00         188   189
# 2016-09-28 23:03:00         337   338
# 2016-08-21 16:07:00         337   338
# 2016-07-02 15:56:00         342   343
# 2016-07-27 05:30:00        1178  1179
# 2016-09-03 08:15:00        1001  1002
# 2016-09-25 11:57:00          77    78
# 2016-07-23 15:39:00        1066  1067
# 2016-08-17 17:30:00         588   589
# 2016-09-30 01:29:00         324   325
# 2016-09-05 21:40:00        1184  1185
#
# [87278 rows x 41 columns]>

# %%
print accidents_data.shape
print crash_WithRoadInfo.shape
print roadnetworkwithbuffer.shape
# Out:
# (87263, 39)
# (87278, 41)
# (1200, 2)

# %%
plt.figure(figsize=(18, 5), dpi=80)
crash_WithRoadInfo["ID"].value_counts().plot(kind='bar')
plt.title("Breakdown of Accidents by Road's")
# Out:
# Text(0.5,1,u"Breakdown of Accidents by Road's")

# %%
plt.figure(figsize=(18, 5), dpi=80)
crash_WithRoadInfo["ID"].value_counts().value_counts().plot(kind='bar')
plt.title("Breakdown of Accidents by Road's")
# Out:
# Text(0.5,1,u"Breakdown of Accidents by Road's")

# %%
#Define a generic function using Pandas replace function
def coding(col, codeDict):
  colCoded = pd.Series(col, copy=True)
  for key, value in codeDict.items():
    colCoded.replace(key, value, inplace=True)
  return colCoded

# %%
#### Some basic code cleanup
crash_WithRoadInfo["LIGHT_CODE_Coded"] = coding(crash_WithRoadInfo["LIGHT_CODE"], 
                                                {0:"Not Applicable",
                                                 1:"Daylight",
                                                 3:"Dark Lights On",
                                                 4:"Dark No Lights",
                                                 5:"Dawn",
                                                 6:"Dusk",
                                                 7:"Dark - Unknown Lighting",
                                                 88:"Other",
                                                 99:"Unknown"})
crash_WithRoadInfo["SURF_COND_CODE"] = coding(crash_WithRoadInfo["SURF_COND_CODE"], 
                                                {0:"Not Applicable",
                                                 1:"Wet",
                                                 2:"Dry",
                                                 3:"Snow",
                                                 4:"Ice",
                                                 5:"Mud, Dirt, Gravel",
                                                 6:"Slush",
                                                 7:"Water (standing/moving)",
                                                 8:"Sand",
                                                 9:"Oil",
                                                 88:"Other",
                                                 99:"Unknown"})
crash_WithRoadInfo["RD_COND_CODE"] = coding(crash_WithRoadInfo["RD_COND_CODE"], 
                                                {0:"Not Applicable",
                                                 1:"No Defects",
                                                 2:"Shoulder Defect",
                                                 3:"Holes, Ruts, Etc.",
                                                 4:"Foreign Material",
                                                 5:"Loose Surface Material",
                                                 6:"Obstruction Not Lighted",
                                                 7:"Obstruction Not Signaled",
                                                 8:"View Obstructed",
                                                 88:"Other"})
crash_WithRoadInfo["WEATHER_CODE"] = coding(crash_WithRoadInfo["WEATHER_CODE"], 
                                                {0:"Not Applicable",
                                                 2:"Foggy",
                                                 3:"Raining",
                                                 5:"Severe Winds",
                                                 6.01:"Clear",
                                                 7.01:"Cloudy",
                                                 8.04:"Snow",
                                                 9.04:"Sleet",
                                                 10.04:"Blowing Snow",
                                                 11.88:"Blowing Sand, Soil, Dirt",
                                                 12.04:"Wintry Mix",
                                                 88:"Other",
                                                 99:"Unknown"})

# %%
featureSet = crash_WithRoadInfo[['datetime','LIGHT_CODE',
                'SURF_COND_CODE','RD_COND_CODE','WEATHER_CODE','DISTANCE','hour','weekday','ID','LIGHT_CODE_Coded']]
featureSet.to_csv("./featuresSet_nn.csv")

# %%
featureSet["hour"] = coding(featureSet["hour"],{1:"Night",
                                                 2:"Night",
                                                 3:"Night",
                                                 4:"Night",
                                                 5:"Night",
                                                 6:"Night",
                                                 7:"Morning",
                                                 8:"Morning",
                                                 9:"Morning",
                                                 10:"Morning",
                                                 11:"Afternoon",
                                                 12:"Afternoon",
                                                 13:"Afternoon",
                                                 14:"Afternoon",
                                                 15:"Afternoon",
                                                 16:"Evening",
                                                 17:"Evening",
                                                 18:"Evening",
                                                 19:"Evening",
                                                 20:"Evening",
                                                 21:"Evening",
                                                 22:"Night",
                                                 23:"Night",
                                                 0:"Night"})
featureSet["date"] = featureSet.datetime.dt.date
# Out:
# /Users/212475040/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/212475040/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
featureSet["month"] = featureSet.datetime.dt.month
featureSet.columns
# Out:
# /Users/212475040/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# Index([        u'datetime',       u'LIGHT_CODE',   u'SURF_COND_CODE',
#            u'RD_COND_CODE',     u'WEATHER_CODE',         u'DISTANCE',
#                    u'hour',          u'weekday',               u'ID',
#        u'LIGHT_CODE_Coded',             u'date',            u'month'],
#       dtype='object')

# %%
featureSet_1 = featureSet.groupby(["ID","date","month","weekday","hour"]).size().to_frame(name = 'count').reset_index()

# %%
# I am here!
featureSet_2 = featureSet.groupby(["ID","date","month","weekday","hour"]).apply(lambda x:x["WEATHER_CODE"].value_counts().index[0]).to_frame(name = 'WEATHER_CODE').reset_index()

# %%
featureSet_1["date"] = featureSet_1["date"].astype('datetime64[ns]')

# %%
featureSet_3 = pd.merge(featureSet_1,featureSet_2,on=["ID","date","month","weekday","hour"], how='inner')

# %%
featureSet_3.to_csv("featureSet_3.csv",index=False)

# %%
featureSet_3["ID"] = featureSet_3["ID"].astype('Int32')

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
import time

from sklearn import preprocessing
data_1 = pd.get_dummies(featureSet_3, columns=["weekday", "hour","WEATHER_CODE","month"])
print data_1.columns

 # Utility function to report best scores
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                    results['mean_test_score'][candidate],
                    results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")
    
    
    # Split Dataframe to Train/Test Split
msk = np.random.rand(len(data_1)) < 0.8
train = data_1[msk]
test = data_1[~msk]

rf = RandomForestRegressor()

    # use a full grid over all parameters
    
param_grid = {"n_estimators": [100,200,500,1000],
                  "max_features": [10,15,20,26,30],
                  "oob_score": [True]
                 }

    # run grid search
grid_search = GridSearchCV(rf, param_grid=param_grid)
start = time.time()
grid_search.fit(train[["ID","month_1", 'month_2', 'month_3',
       'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 'month_9',
                "weekday_Friday","weekday_Monday","weekday_Saturday","weekday_Sunday","weekday_Thursday",
                "weekday_Tuesday","weekday_Wednesday",
                "hour_Afternoon","hour_Evening","hour_Morning","hour_Night",
                "WEATHER_CODE_Blowing Sand, Soil, Dirt","WEATHER_CODE_Blowing Snow","WEATHER_CODE_Clear","WEATHER_CODE_Cloudy",
                "WEATHER_CODE_Foggy","WEATHER_CODE_Not Applicable","WEATHER_CODE_Other","WEATHER_CODE_Raining",
                "WEATHER_CODE_Severe Winds","WEATHER_CODE_Sleet","WEATHER_CODE_Snow","WEATHER_CODE_Unknown",
                "WEATHER_CODE_Wintry Mix" ]], train["count"])
    
    
print("GridSearchCV took %.2f seconds for %d candidate parameter settings."
          % (time.time() - start, len(grid_search.cv_results_['params'])))
report(grid_search.cv_results_)
# Out:
# Index([u'ID', u'date', u'count', u'weekday_Friday', u'weekday_Monday',
#        u'weekday_Saturday', u'weekday_Sunday', u'weekday_Thursday',
#        u'weekday_Tuesday', u'weekday_Wednesday', u'hour_Afternoon',
#        u'hour_Evening', u'hour_Morning', u'hour_Night',
#        u'WEATHER_CODE_Blowing Sand, Soil, Dirt', u'WEATHER_CODE_Blowing Snow',
#        u'WEATHER_CODE_Clear', u'WEATHER_CODE_Cloudy', u'WEATHER_CODE_Foggy',
#        u'WEATHER_CODE_Not Applicable', u'WEATHER_CODE_Other',
#        u'WEATHER_CODE_Raining', u'WEATHER_CODE_Severe Winds',
#        u'WEATHER_CODE_Sleet', u'WEATHER_CODE_Snow', u'WEATHER_CODE_Unknown',
#        u'WEATHER_CODE_Wintry Mix', u'month_1', u'month_2', u'month_3',
#        u'month_4', u'month_5', u'month_6', u'month_7', u'month_8', u'month_9'],
#       dtype='object')
# GridSearchCV took 1161.54 seconds for 20 candidate parameter settings.
# Model with rank: 1
# Mean validation score: -0.103 (std: 0.099)
# Parameters: {'max_features': 26, 'n_estimators': 500, 'oob_score': True}
#
# Model with rank: 2
# Mean validation score: -0.103 (std: 0.096)
# Parameters: {'max_features': 26, 'n_estimators': 200, 'oob_score': True}
#
# Model with rank: 3
# Mean validation score: -0.104 (std: 0.098)
# Parameters: {'max_features': 26, 'n_estimators': 1000, 'oob_score': True}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
import time

from sklearn import preprocessing
data_1 = pd.get_dummies(featureSet_3, columns=["weekday", "hour","WEATHER_CODE"])

 # Utility function to report best scores
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                    results['mean_test_score'][candidate],
                    results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")
            
predictorforGrid = {}

# Split Dataframe to Train/Test Split
msk = np.random.rand(len(data_1)) < 0.8
train = data_1[msk]
test = data_1[~msk]

for x in data_1['ID'].unique():

    data_2 = train.loc[train['ID'] == x]
    
    print x
    print data_2.shape[0] 
    
    if data_2.shape[0] < 12:
        continue

    rf = RandomForestRegressor()

    # use a full grid over all parameters
    param_grid = {"n_estimators": [2,3,4,5],
                  "max_features": [12,16,20],
                  "oob_score": [True,False]}

    # run grid search
    grid_search = GridSearchCV(rf, param_grid=param_grid)
    start = time.time()
    grid_search.fit(data_2[["month",
                "weekday_Friday","weekday_Monday","weekday_Saturday","weekday_Sunday","weekday_Thursday",
                "weekday_Tuesday","weekday_Wednesday",
                "hour_Afternoon","hour_Evening","hour_Morning","hour_Night",
                "WEATHER_CODE_Blowing Sand, Soil, Dirt","WEATHER_CODE_Blowing Snow","WEATHER_CODE_Clear","WEATHER_CODE_Cloudy",
                "WEATHER_CODE_Foggy","WEATHER_CODE_Not Applicable","WEATHER_CODE_Other","WEATHER_CODE_Raining",
                "WEATHER_CODE_Severe Winds","WEATHER_CODE_Sleet","WEATHER_CODE_Snow","WEATHER_CODE_Unknown",
                "WEATHER_CODE_Wintry Mix" ]], data_2["count"])
    
    #predictorforGrid.add((x,grid_search.best_estimator_))
    #predictorforGrid.append(tuple((x, grid_search.best_estimator_)))
    predictorforGrid[x] = grid_search.best_estimator_
    #print("GridSearchCV took %.2f seconds for %d candidate parameter settings."
    #      % (time.time() - start, len(grid_search.cv_results_['params'])))
    #report(grid_search.cv_results_)
# Out:
# 10
# 23
# 100
# 148
# 1000
# 1
# 1001
# 1
# 1002
# 1
# 1003
# 12
# 1004
# 15
# 1005
# 63
# 1006
# 6
# 1007
# 4
# 101
# 179
# 102
# 232
# 103
# 53
# 1052
# 1
# 1057
# 1
# 1058
# 2
# 1062
# 20
# 1063
# 7
# 1064
# 2
# 1065
# 11
# 1066
# 3
# 1067
# 1
# 11
# 16
# 1179
# 1
# 1185
# 1
# 12
# 14
# 126
# 3
# 127
# 31
# 128
# 19
# 129
# 3
# 13
# 40
# 130
# 18
# 131
# 8
# 132
# 4
# 135
# 5
# 136
# 1
# 14
# 22
# 142
# 6
# 143
# 31
# 144
# 80
# 145
# 85
# 146
# 66
# 147
# 80
# 148
# 37
# 149
# 23
# 15
# 13
# 150
# 67
# 151
# 97
# 152
# 201
# 153
# 89
# 154
# 386
# 155
# 80
# 156
# 75
# 157
# 362
# 158
# 207
# 159
# 159
# 16
# 16
# 160
# 13
# 161
# 11
# 162
# 32
# 163
# 8
# 17
# 16
# 18
# 22
# 182
# 1
# 186
# 28
# 187
# 34
# 188
# 10
# 189
# 2
# 19
# 32
# 191
# 1
# 20
# 7
# 203
# 4
# 204
# 9
# 205
# 66
# 206
# 471
# 207
# 172
# 208
# 100
# 209
# 130
# 21
# 18
# 210
# 61
# 211
# 142
# 212
# 304
# 213
# 719
# 214
# 771
# 215
# 750
# 216
# 529
# 217
# 247
# 218
# 47
# 219
# 1
# 22
# 40
# 220
# 3
# 221
# 9
# 222
# 27
# 223
# 7
# 225
# 1
# 23
# 165
# 24
# 36
# 246
# 12
# 247
# 4
# 25
# 15
# 26
# 28
# 263
# 10
# 264
# 49
# 265
# 43
# 266
# 44
# 267
# 182
# 268
# 97
# 269
# 35
# 27
# 43
# 270
# 88
# 271
# 126
# 272
# 272
# 273
# 756
# 274
# 882
# 275
# 873
# 276
# 680
# 277
# 49
# 279
# 3
# 28
# 12
# 280
# 8
# 281
# 19
# 282
# 22
# 283
# 5
# 29
# 34
# 30
# 27
# 31
# 21
# 32
# 50
# 322
# 1
# 325
# 1
# 326
# 18
# 327
# 27
# 328
# 549
# 329
# 246
# 33
# 15
# 330
# 106
# 331
# 96
# 332
# 459
# 333
# 521
# 334
# 737
# 335
# 311
# 336
# 69
# 337
# 1
# 338
# 2
# 339
# 12
# 34
# 53
# 340
# 54
# 341
# 17
# 342
# 20
# 343
# 0
# 35
# 13
# 36
# 24
# 37
# 41
# 38
# 17
# 386
# 9
# 387
# 41
# 388
# 379
# 389
# 664
# 39
# 53
# 390
# 512
# 391
# 434
# 392
# 569
# 393
# 316
# 394
# 494
# 395
# 472
# 396
# 60
# 397
# 3
# 398
# 3
# 399
# 2
# 40
# 64
# 400
# 18
# 401
# 24
# 402
# 12
# 403
# 16
# 41
# 51
# 42
# 55
# 43
# 9
# 446
# 2
# 447
# 2
# 448
# 63
# 449
# 491
# 450
# 725
# 451
# 791
# 452
# 552
# 453
# 273
# 454
# 296
# 455
# 526
# 456
# 277
# 457
# 69
# 458
# 66
# 459
# 72
# 460
# 71
# 461
# 15
# 462
# 21
# 463
# 21
# 502
# 1
# 508
# 1
# 509
# 6
# 510
# 3
# 511
# 578
# 512
# 653
# 513
# 328
# 514
# 63
# 515
# 165
# 516
# 24
# 517
# 10
# 518
# 4
# 519
# 9
# 520
# 39
# 521
# 27
# 522
# 77
# 523
# 13
# 546
# 1
# 570
# 136
# 571
# 618
# 572
# 468
# 573
# 179
# 574
# 58
# 575
# 78
# 576
# 0
# 577
# 6
# 578
# 12
# 579
# 14
# 580
# 229
# 581
# 19
# 582
# 14
# 583
# 10
# 589
# 1
# 6
# 19
# 629
# 1
# 630
# 54
# 631
# 192
# 632
# 294
# 633
# 15
# 634
# 143
# 635
# 72
# 637
# 1
# 639
# 7
# 640
# 40
# 641
# 16
# 642
# 29
# 643
# 25
# 66
# 0
# 67
# 26
# 68
# 9
# 683
# 1
# 688
# 1
# 689
# 34
# 69
# 3
# 690
# 109
# 691
# 441
# 692
# 219
# 693
# 32
# 694
# 69
# 695
# 72
# 696
# 1
# 698
# 3
# 699
# 1
# 7
# 10
# 70
# 3
# 700
# 133
# 701
# 37
# 702
# 35
# 703
# 11
# 71
# 25
# 710
# 1
# 72
# 93
# 73
# 42
# 74
# 3
# 748
# 8
# 749
# 25
# 75
# 0
# 750
# 49
# 751
# 176
# 752
# 39
# 753
# 120
# 754
# 42
# 755
# 105
# 756
# 9
# 759
# 5
# 760
# 10
# 761
# 12
# 762
# 20
# 763
# 25
# 765
# 38
# 766
# 2
# 767
# 0
# 768
# 2
# 770
# 2
# 78
# 1
# 8
# 21
# 80
# 9
# 808
# 3
# 809
# 5
# 81
# 18
# 810
# 2
# 811
# 39
# 812
# 21
# 813
# 63
# 814
# 48
# 815
# 19
# 816
# 83
# 818
# 1
# 819
# 3
# 82
# 88
# 820
# 2
# 822
# 1
# 823
# 9
# 824
# 238
# 825
# 375
# 826
# 57
# 827
# 38
# 828
# 41
# 829
# 93
# 83
# 403
# 830
# 216
# 84
# 149
# 85
# 31
# 86
# 66
# 869
# 1
# 87
# 22
# 871
# 6
# 872
# 9
# 873
# 24
# 874
# 114
# 875
# 183
# 876
# 200
# 878
# 1
# 88
# 14
# 881
# 1
# 882
# 9
# 883
# 2
# 884
# 142
# 885
# 105
# 886
# 6
# 887
# 5
# 888
# 52
# 889
# 104
# 89
# 33
# 890
# 142
# 9
# 24
# 90
# 74
# 91
# 254
# 92
# 93
# 93
# 21
# 930
# 0
# 933
# 4
# 934
# 2
# 935
# 54
# 936
# 70
# 937
# 13
# 94
# 76
# 941
# 3
# 942
# 7
# 943
# 14
# 944
# 71
# 945
# 3
# 946
# 14
# 947
# 35
# 948
# 5
# 949
# 2
# 95
# 36
# 96
# 57
# 97
# 127
# 98
# 80
# 99
# 124
# 995
# 1
# 997
# 6

# %%
print predictorforGrid
print test['ID']
# Out:
# {512: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=4, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 513: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 514: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 515: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 516: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 6: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 520: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 521: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 10: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 11: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 12: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 13: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 14: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 15: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 16: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 17: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=4, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 18: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 19: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 21: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 22: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 23: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 24: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 25: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 26: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 27: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 28: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 29: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 30: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 31: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 32: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 33: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 34: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=4, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 35: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 36: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 37: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 1062: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 39: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 40: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 41: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 42: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 8: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 9: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 570: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 571: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 572: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=4, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 522: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 574: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 575: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 578: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 523: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 580: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 581: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 582: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 71: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 72: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 73: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 81: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 82: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 83: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 84: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 85: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 86: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 87: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 88: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 89: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 90: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 91: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 92: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 93: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 94: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 95: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 96: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 97: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 98: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 99: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 100: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 101: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 102: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 103: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 630: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=4, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 631: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 632: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 633: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 634: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 635: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 127: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 128: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 641: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 130: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 643: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 143: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 144: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 145: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 146: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 147: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 148: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 149: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 150: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 151: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 152: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=4, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 153: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 154: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 155: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 156: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=4, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 157: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 158: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=4, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 159: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 160: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 162: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 642: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 689: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 690: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=4, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 691: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 692: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=4, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 693: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 694: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 695: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 186: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 187: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 700: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=4, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 701: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 702: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 205: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 206: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 207: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=4, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 208: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
# ...
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 391: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 392: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 393: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 394: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 395: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 396: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 400: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 401: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 402: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 403: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 935: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 936: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 937: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 943: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 944: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 946: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 947: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 448: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 449: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 450: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 451: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 452: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=4, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 453: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 454: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 455: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=4, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 456: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=5, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 457: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=4, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 458: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 459: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 460: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=3, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 461: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 462: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 463: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 67: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 1003: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 1004: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 1005: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=20, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), 579: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=12, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=2, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False), 511: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=16, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=4, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False)}
# 2         10
# 7         10
# 8         10
# 11        10
# 14        10
# 19        10
# 29       100
# 30       100
# 33       100
# 38       100
# 39       100
# 42       100
# 48       100
# 52       100
# 53       100
# 71       100
# 72       100
# 77       100
# 79       100
# 86       100
# 88       100
# 93       100
# 97       100
# 103      100
# 106      100
# 107      100
# 112      100
# 116      100
# 118      100
# 121      100
#         ...
# 44859     99
# 44871     99
# 44875     99
# 44877     99
# 44881     99
# 44883     99
# 44888     99
# 44893     99
# 44900     99
# 44901     99
# 44908     99
# 44909     99
# 44910     99
# 44912     99
# 44914     99
# 44923     99
# 44924     99
# 44927     99
# 44933     99
# 44934     99
# 44935     99
# 44938     99
# 44942     99
# 44953     99
# 44966     99
# 44969     99
# 44973     99
# 44998    997
# 44999    997
# 45000    997
# Name: ID, Length: 8888, dtype: int32

# %%
def dfPredict(row):
    model = predictorforGrid.get(row["ID"].astype(str))
    predicted_count = 0
    if model is not None:
        predicted_count = model.predict(row[["month",
            "weekday_Friday","weekday_Monday","weekday_Saturday","weekday_Sunday","weekday_Thursday",
            "weekday_Tuesday","weekday_Wednesday",
            "hour_Afternoon","hour_Evening","hour_Morning","hour_Night",
            "WEATHER_CODE_Blowing Sand, Soil, Dirt","WEATHER_CODE_Blowing Snow","WEATHER_CODE_Clear","WEATHER_CODE_Cloudy",
            "WEATHER_CODE_Foggy","WEATHER_CODE_Not Applicable","WEATHER_CODE_Other","WEATHER_CODE_Raining",
            "WEATHER_CODE_Severe Winds","WEATHER_CODE_Sleet","WEATHER_CODE_Snow","WEATHER_CODE_Unknown",
            "WEATHER_CODE_Wintry Mix" ]])
    return predicted_count

test.apply(dfPredict,axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-113-247294819582> in <module>()
#      14     return predicted_count
#      15
# ---> 16 test.apply(dfPredict,axis=1)
#
# /Users/212475040/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4875                         f, axis,
#    4876                         reduce=reduce,
# -> 4877                         ignore_failures=ignore_failures)
#    4878             else:
#    4879                 return self._apply_broadcast(f, axis)
#
# /Users/212475040/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4971             try:
#    4972                 for i, v in enumerate(series_gen):
# -> 4973                     results[i] = func(v)
#    4974                     keys.append(v.name)
#    4975             except Exception as e:
#
# <ipython-input-113-247294819582> in dfPredict(row)
#       1 def dfPredict(row):
# ----> 2     model = predictorforGrid.get(row["ID"].astype(str))
#       3     print model
#       4     predicted_count = 0
#       5     if model is not None:
#
# AttributeError: ("'int' object has no attribute 'astype'", u'occurred at index 2')

# %%
print test["count_predict"].unique()
# Out:
# [0]

# %%
test["count_predict"] = rf.predict(test[["ID","month_1", 'month_2', 'month_3',
       'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 'month_9',
            "weekday_Friday","weekday_Monday","weekday_Saturday","weekday_Sunday","weekday_Thursday",
            "weekday_Tuesday","weekday_Wednesday",
            "hour_Afternoon","hour_Evening","hour_Morning","hour_Night",
            "WEATHER_CODE_Blowing Sand, Soil, Dirt","WEATHER_CODE_Blowing Snow","WEATHER_CODE_Clear","WEATHER_CODE_Cloudy",
            "WEATHER_CODE_Foggy","WEATHER_CODE_Not Applicable","WEATHER_CODE_Other","WEATHER_CODE_Raining",
            "WEATHER_CODE_Severe Winds","WEATHER_CODE_Sleet","WEATHER_CODE_Snow","WEATHER_CODE_Unknown",
            "WEATHER_CODE_Wintry Mix" ]])
